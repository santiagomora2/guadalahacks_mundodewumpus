# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('pd_speech_features.csv')
df.head()
# Out:
#    id  gender      PPE      DFA     RPDE  numPulses  numPeriodsPulses  \
# 0   0       1  0.85247  0.71826  0.57227        240               239
# 1   0       1  0.76686  0.69481  0.53966        234               233
# 2   0       1  0.85083  0.67604  0.58982        232               231
# 3   1       0  0.41121  0.79672  0.59257        178               177
# 4   1       0  0.32790  0.79782  0.53028        236               235
#
#    meanPeriodPulses  stdDevPeriodPulses  locPctJitter  ...  \
# 0          0.008064            0.000087       0.00218  ...
# 1          0.008258            0.000073       0.00195  ...
# 2          0.008340            0.000060       0.00176  ...
# 3          0.010858            0.000183       0.00419  ...
# 4          0.008162            0.002669       0.00535  ...
#
#    tqwt_kurtosisValue_dec_28  tqwt_kurtosisValue_dec_29  \
# 0                     1.5620                     2.6445
# 1                     1.5589                     3.6107
# ...

# %%
df.shape
# Out:
# (756, 755)

# %%
from sklearn.utils import resample

df_majority = df[df.iloc[:,754]==1]
df_minority = df[df.iloc[:,754]==0]
 
# Downsample majority class
df_majority_downsampled = resample(df_majority, 
                                 replace=False,    
                                 n_samples=130)
#Upsample minority class
df_minority_upsampled = resample(df_minority, 
                                 replace=True,     
                                 n_samples=190)
# Combine minority class with downsampled majority class
df_up_down_sampled = pd.concat([df_majority_downsampled, df_minority_upsampled])

# %%
df['locAbsJitter']
# Out:
# 0      0.000018
# 1      0.000016
# 2      0.000015
# 3      0.000046
# 4      0.000044
#          ...
# 751    0.000003
# 752    0.000006
# 753    0.000004
# 754    0.000005
# 755    0.000004
# Name: locAbsJitter, Length: 756, dtype: float64

# %%
# MFCC: Col_57 to Col_140
df_MFCC = df_up_down_sampled.iloc[:, 56:140]
df_MFCC.drop(columns = ['mean_Log_energy', 'mean_delta_log_energy', 'mean_delta_delta_log_energy', 'std_Log_energy', 'std_delta_log_energy', 'std_delta_delta_log_energy'], inplace = True)
df_MFCC_ = df_MFCC.iloc[:, 5:]
df_MFCC_.head()
# Out:
#      mean_MFCC_5th_coef  mean_MFCC_6th_coef  mean_MFCC_7th_coef  \
# 134            -0.71924            -2.58840            -0.94677
# 367            -2.01670            -1.19160             0.82728
# 691            -0.97007            -1.30520            -0.94954
# 255            -0.26353            -0.61793            -1.00480
# 681             0.86010            -1.12240             0.44865
#
#      mean_MFCC_8th_coef  mean_MFCC_9th_coef  mean_MFCC_10th_coef  \
# 134            1.500300             1.14310             -0.78888
# 367           -0.124260            -1.63390             -1.07380
# 691           -0.983260            -0.81902             -0.19031
# 255            0.705450            -1.60410             -1.89570
# 681           -0.028754             0.52872             -0.42563
#
#      mean_MFCC_11th_coef  mean_MFCC_12th_coef  mean_0th_delta  mean_1st_delta  \
# 134              0.38759              0.33542        0.001476       -0.002233
# ...

# %%
df_idgen = df_up_down_sampled.iloc[:, 0:2]
df_idgen.head()
# Out:
#       id  gender
# 134   44       1
# 367  122       0
# 691  230       0
# 255   85       1
# 681  227       1

# %%
df_class = df_up_down_sampled.loc[:, 'class']
df_class.head()
# Out:
# 134    1
# 367    1
# 691    1
# 255    1
# 681    1
# Name: class, dtype: int64

# %%
df_ = pd.concat([df_MFCC_, df_class], axis = 1)
df_.head()
# Out:
#      mean_MFCC_5th_coef  mean_MFCC_6th_coef  mean_MFCC_7th_coef  \
# 134            -0.71924            -2.58840            -0.94677
# 367            -2.01670            -1.19160             0.82728
# 691            -0.97007            -1.30520            -0.94954
# 255            -0.26353            -0.61793            -1.00480
# 681             0.86010            -1.12240             0.44865
#
#      mean_MFCC_8th_coef  mean_MFCC_9th_coef  mean_MFCC_10th_coef  \
# 134            1.500300             1.14310             -0.78888
# 367           -0.124260            -1.63390             -1.07380
# 691           -0.983260            -0.81902             -0.19031
# 255            0.705450            -1.60410             -1.89570
# 681           -0.028754             0.52872             -0.42563
#
#      mean_MFCC_11th_coef  mean_MFCC_12th_coef  mean_0th_delta  mean_1st_delta  \
# 134              0.38759              0.33542        0.001476       -0.002233
# ...

# %%
X = df_.iloc[:, :-1]
y = df_.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1234, stratify = y)
# Out:
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %% [markdown]
# # LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression

LR = LogisticRegression()
LR.fit(X_train, y_train);
# Out:
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# ...

# %%
y_pred = LR.predict(X_test)

accuracy = (y_test == y_pred).mean()
accuracy
# Out:
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# ...

# %%
from sklearn.model_selection import cross_validate;

cv_8 = cross_validate(estimator = LR,
                      cv = 8,
                      X = X_train,
                      y = y_train);
# Out:
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# ...

# %%
res = pd.DataFrame(cv_8)
res.agg(["mean", "sem"])
# Out:
#       fit_time  score_time  test_score
# mean  0.016219    0.007379    0.671875
# sem   0.001546    0.001401    0.031803

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC


SVMC = SVC(kernel = 'sigmoid')
SVMC.fit(X_train, y_train);
# Out:
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# ...

# %%
y_pred = SVMC.predict(X_test)
accuracy = (y_test == y_pred).mean()
accuracy
# Out:
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# ...

# %%
cv_8 = cross_validate(estimator = SVMC,
                      cv = 8,
                      X = X_train,
                      y = y_train);
# Out:
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# ...

# %%
res = pd.DataFrame(cv_8)
res.agg(["mean", "sem"])
# Out:
#       fit_time  score_time  test_score
# mean  0.006784    0.006904    0.621094
# sem   0.001251    0.001263    0.027974

# %% [markdown]
# # SVMC (otro kernel)

# %%
SVMC1 = SVC(kernel = 'linear')
SVMC1.fit(X_train, y_train);
# Out:
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# ...

# %%
cv_8 = cross_validate(estimator = SVMC1,
                      cv = 8,
                      X = X_train,
                      y = y_train);
# Out:
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# ...

# %%
res = pd.DataFrame(cv_8)
res.agg(["mean", "sem"])
# Out:
#       fit_time  score_time  test_score
# mean  0.010324    0.004378    0.722656
# sem   0.001502    0.001482    0.022440

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
KNNC = KNeighborsClassifier()
KNNC.fit(X_train, y_train);
# Out:
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# ...

# %%
y_pred = KNNC.predict(X_test)
accuracy = (y_test == y_pred).mean()
accuracy
# Out:
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# ...

# %%
cv_8 = cross_validate(estimator = KNNC,
                      cv = 8,
                      X = X_train,
                      y = y_train);
# Out:
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# ...

# %%
res = pd.DataFrame(cv_8)
res.agg(["mean", "sem"])
# Out:
#       fit_time  score_time  test_score
# mean  0.006413    0.011071    0.699219
# sem   0.001498    0.000645    0.024305

# %% [markdown]
# # arbOles

# %%
from sklearn.ensemble import RandomForestClassifier
RFC = RandomForestClassifier(random_state = 0)
RFC.fit(X_train, y_train);
# Out:
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# ...

# %%
y_pred = RFC.predict(X_test)
accuracy = (y_test == y_pred).mean()
accuracy
# Out:
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# ...

# %%
cv_8 = cross_validate(estimator = RFC,
                      cv = 8,
                      X = X_train,
                      y = y_train);
res = pd.DataFrame(cv_8)
res.agg(["mean", "sem"])
# Out:
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# ...

# %%
#modelos = LR, SVMC, KNNC, RFC, SVMC1
import joblib

# %%
ref_cols = list(X.columns)
target = 'class'

# %%
joblib.dump(value = [LR, ref_cols, target], filename = 'LR.pkl')
joblib.dump(value = [SVMC, ref_cols, target], filename = 'SVMC.pkl')
joblib.dump(value = [SVMC1, ref_cols, target], filename = 'SVMC1.pkl')
joblib.dump(value = [KNNC, ref_cols, target], filename = 'KNNC.pkl')
joblib.dump(value = [RFC, ref_cols, target], filename = 'RFC.pkl')
# Out:
# ['RFC.pkl']

# %%
def voting(dataF):
    X_ = dataF[ref_cols]

    predicts = []
    models = [LR, SVMC, SVMC1, RFC, KNNC]

    for item in models:
        predicts.append(item.predict(X_)[0])
    
    mean = (predicts[0]+predicts[1]+predicts[2]+predicts[3]+predicts[4])/5

    if mean > 0.65:
        return 1
    else:
        return 0

# %%
ejemplo = df_.sample(1)
print('Class Real:', end=' ')
print(ejemplo['class'])
print('Class Predict:', end=' ')
print(voting(ejemplo))
# Out:
# Class Real: 392    0
# Name: class, dtype: int64
# Class Predict: 0
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# ...

# %%
ejemplo = df_MFCC.sample(1)
voting(df_MFCC.sample(1))
# Out:
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\santi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# ...
